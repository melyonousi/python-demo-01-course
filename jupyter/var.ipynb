# %% [markdown]
# > display data

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# > get data from user

# %%
name = input("your name plz: ")
print("hello", name)
# Out:
# hello Mohamed

# %%
firstName = "Mohamed EL YONOUSI"

# %%
print(firstName)
# Out:
# Mohamed EL YONOUSI

# %% [markdown]
# # big title

# %% [markdown]
# ## big title

# %% [markdown]
# ### big title

# %% [markdown]
# > make a table with markdown
#
# nom  |   prenom  |  classe
# -----|-----------|---------
# a    |     b     |    c
# ab   |     bc    |    cd

# %% [markdown]
# > make a list with markdown
#
#
# 1. Maroc
# 2. Algerie
# 3. Tunisie

# %% [markdown]
# > make a list with markdown
#
# * Python
#   - input
#   - print
#   - condition
# * HTML
#   - images
#   - URL's

# %% [markdown]
# ![wakeup](https://images.unsplash.com/photo-1558349768-279a6d352b66?ixlib=rb-1.2.1&ixid=MnwxMjA3fDB8MHxzZWFyY2h8MTR8fHdha2V1cHxlbnwwfHwwfHw%3D&auto=format&fit=crop&w=500&q=60)

# %% [markdown]
# ![screenshot](C:\Users\melyo\Downloads\whatsapp_image.jpeg)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo("https://youtu.be/Tbh7y3-Prx0?t=22")

# %% [markdown]
# > python script in markdown
#
# ~~~python
# from IPython.display import YouTubeVideo
# YouTubeVideo("https://youtu.be/Tbh7y3-Prx0?t=22")
# ~~~
#
# > javascript
#
# ~~~javascript
# console.log("hello world");
# ~~~
#
# > css
#
# ~~~css
# .main{
#     color: #ffaa00;
#     padding: 1em;
#     background-color: #1f1f1f;
#     border-raduis: 1em;
# }
# ~~~

# %% [markdown]
# > math expressions
#
# $🛆: b^2 - 4ac$

# %% [markdown]
# > code HTML
#
# <div style="display: flex;
#             justify-content: center;
#             align-items: center;">
#     <div style="width: 500px;
#             display: flex;
#             flex-direction: row;
#             justify-content: center;
#             align-items: center;
#             gap: 1em;
#             background-color: #ffaa00;
#             color: white;
#             padding: 1em;
#             border-radius: 0.5em;">
#         <img src="https://bl3302files.storage.live.com/y4m6Lx5J0ZIciygUxX9sKrAQEkvz_rSC2yE0loDFx54OmWeW9Ypi2GlgAxsvKeNPIePT1zp1hFWvN-EdNijyZMD0Pw85nePiLtAMyps8rpkRvMvh-4GOPeO6cp6EyU3S93e5G3Cq6gR-aCfNA7WlKVfQFtHZTTimsbLzT1CcKfttv7c2jH3DVfWAmbIYeQvhDV9?width=200&height=200&cropmode=none" alt="Mohamed EL YONOUSI" style="border-radius: 0.5em;">
#         <div style="width: fit-content;
#                 display: flex;
#                 flex-direction: column;">
#             <h3 style="margin: 0;">Mohamed EL YONOUSI</h3>
#             <span><strong>Borthday: </strong>05-03-1996</span>
#             <span><strong>Status: </strong>Developer</span>
#             <address><strong>Address: </strong>Boujrah, avenue Jabal Boublan, Rue 6,
#                 résidence Moraes,
#                 deuxième étage, appartement 13
#             </address>
#             <span><strong>Country: </strong>Morocco</span>
#             <span><strong>City: </strong>Tetouan</span>
#         </div>
#     </div>
# </div>
